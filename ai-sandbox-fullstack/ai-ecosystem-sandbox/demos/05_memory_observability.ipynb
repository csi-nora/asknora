# %% [markdown]
# # Demo 05 — Memory & Observability
#
# Redis session memory + LangSmith/Langfuse tracing hooks.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve().parent))

from src.providers.memory import new_session_id, remember, recall
from src.providers.observability import setup_langsmith, trace_span

print('LangSmith:', setup_langsmith())
sid = new_session_id()
with trace_span('nb05.demo', {'session': sid}):
    remember(sid, 'user', 'Prefer Ollama for local inference.')
    remember(sid, 'assistant', 'Noted.')
recall(sid)
