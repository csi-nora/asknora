# %% [markdown]
# # Demo 06 — Tool Calling & Automation
#
# LangChain agent with **calculator**, **DuckDuckGo search**, and **Wikipedia**.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve().parent))

from src.providers.tools import run_langchain_agent

q = 'What is 25 * 4 + 10? Also look up Langfuse in one sentence.'
run_langchain_agent(q)
