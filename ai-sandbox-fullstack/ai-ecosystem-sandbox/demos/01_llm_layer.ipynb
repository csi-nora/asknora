# %% [markdown]
# # Demo 01 — LLM Layer
#
# OpenAI / Anthropic / Google / Groq with **Ollama fallback**.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve().parent))

from src.providers.llm_router import chat, list_available_providers
from src.providers.observability import trace_span

list_available_providers()

# %%
prompt = 'Explain LangGraph vs CrewAI in 3 bullet points.'
with trace_span('nb01.llm'):
    result = chat(prompt)
print(result.provider, result.model)
print(result.text)
