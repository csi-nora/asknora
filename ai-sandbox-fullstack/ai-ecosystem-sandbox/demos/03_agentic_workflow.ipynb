# %% [markdown]
# # Demo 03 — Agentic Workflow
#
# **LangGraph** research → write → review pipeline.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve().parent))

from src.providers.agents import langgraph_research_write_review

result = langgraph_research_write_review('Observability tools for LLM applications')
for k in ('research', 'draft', 'review'):
    print(f'\n=== {k.upper()} ===\n', result[k])

# %%
from src.providers.agents import crewai_demo
print(crewai_demo('Vector databases for RAG'))
